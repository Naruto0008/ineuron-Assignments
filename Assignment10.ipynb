# %%
1. How do you distinguish between shutil.copy() and shutil.copytree()?
2. What function is used to rename files??
3. What is the difference between the delete functions in the send2trash and shutil modules?
4.ZipFile objects have a close() method just like File objects’ close() method.
What ZipFile method is equivalent to File objects’ open() method?
5. Create a programme that searches a folder tree for files with a certain file extension (such as .pdf or .jpg).
Copy these files from whatever location they are in to a new folder.

# %%
1. How do you distinguish between shutil.copy() and shutil.copytree()?

# %%
shutil.copy() will copy a single file,while shutil.copytree() will copy the entire folder

# %%
2. What function is used to rename files??

# %%
shutil.move() function will help in both renaming,moving the files

# %%
3. What is the difference between the delete functions in the send2trash and shutil modules?

# %%
Send2trash will delete the files and put in trash bin of system,while shuttle rmtree will delete permanantly without leaving a trace

# %%
4.ZipFile objects have a close() method just like File objects’ close() method.
What ZipFile method is equivalent to File objects’ open() method?

# %%
Zipfile.Zipfile method  equivalent to file objects open method

# %%
5. Create a programme that searches a folder tree for files with a certain file extension (such as .pdf or .jpg).
Copy these files from whatever location they are in to a new folder

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\narsi'

# %%
os.listdir()
# Out:
# ['.android',
#  '.astropy',
#  '.conda',
#  '.condarc',
#  '.continuum',
#  '.gitconfig',
#  '.idlerc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.matplotlib',
#  '.python_history',
#  '.wdc',
#  '.wdm',
#  '07 Functions_Revision (1).ipynb',
#  '3D Objects',
#  'airline.xls',
#  'alcohol.xls',
#  'anaconda3',
#  'AppData',
#  'Application Data',
#  'assign.py.bak',
#  'Assignment 1.ipynb',
#  'Assignment 2.ipynb',
#  'assignment 4.ipynb',
#  'Assignment 6.ipynb',
#  'Assignment 7.ipynb',
#  'Assignment 8.ipynb',
#  'Assignment 9.ipynb',
#  'Assignment10.ipynb',
#  'Assignment3.ipynb',
#  'Assignmet 5.ipynb',
#  'bank',
#  'bank-additional.zip',
#  'bokka',
#  'bumchik.py',
#  'business-price-indexes-december-2021-quarter-csv.zip',
#  'car (1).names',
#  'car.data',
#  'car.names',
#  'Contacts',
#  'Cookies',
#  'day 1.ipynb',
#  'Die Design Fundamentals (J Paquin, Robert Crowley) (z-lib.org).pdf',
#  'Documents',
#  'Downloads',
#  'Exception handling class 1 (1).ipynb',
#  'Exception handling class 2 (1).ipynb',
#  'Favorites',
#  'file sysetm.ipynb',
#  'Function and holiday task (1).ipynb',
#  'Function continued.ipynb',
#  'Fundamentals of Tool Design, 6th Edition (Evans, John W. Hill, Mark Nee etc.) (z-lib.org).pdf',
#  'glass (1).data',
#  'glass(1).data',
#  'Handbook of Die Design (Ivana Suchy) (z-lib.org).pdf',
#  'IntelGraphicsProfiles',
#  'iterator generator.ipynb',
#  'Jigs and Fixtures Design Manual (Prakash Joshi) (z-lib.org).pdf',
#  'jobdb.db',
#  'Links',
#  'Local Settings',
#  'logging (1) (1).ipynb',
#  'logging (1).ipynb',
#  'MicrosoftEdgeBackups',
#  'Music',
#  'My Documents',
#  'mydict.py',
#  'mydict.py.bak',
#  'mydicto',
#  'mydicto.bak',
#  'mym.py',
#  'mym.py.bak',
#  'myownproject',
#  'NetHood',
#  'New folder',
#  'New folder (2)',
#  'new1.py',
#  'neww',
#  'newy',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{5ca571a4-b0ad-11eb-b5a7-f7e952eab096}.TxR.0.regtrans-ms',
#  'NTUSER.DAT{5ca571a4-b0ad-11eb-b5a7-f7e952eab096}.TxR.1.regtrans-ms',
#  'NTUSER.DAT{5ca571a4-b0ad-11eb-b5a7-f7e952eab096}.TxR.2.regtrans-ms',
#  'NTUSER.DAT{5ca571a4-b0ad-11eb-b5a7-f7e952eab096}.TxR.blf',
#  'NTUSER.DAT{5ca571a5-b0ad-11eb-b5a7-f7e952eab096}.TM.blf',
#  'NTUSER.DAT{5ca571a5-b0ad-11eb-b5a7-f7e952eab096}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{5ca571a5-b0ad-11eb-b5a7-f7e952eab096}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'OneDrive',
#  'oops 29th .ipynb',
#  'oops 30th.ipynb',
#  'oops class 1.ipynb',
#  'os and commands.ipynb',
#  'pandas class 3.ipynb',
#  'pandas day 2.ipynb',
#  'Pandas.ipynb',
#  'person.db',
#  'pop.db',
#  'Postman',
#  'practice problem python basic (1).ipynb',
#  'PrintHood',
#  'Python basic (3).ipynb',
#  'pythonProject',
#  'Recent',
#  'Saved Games',
#  'Searches',
#  'SendTo',
#  'Sheet metal forming processes and die design (Boljanovic, Vukota) (z-lib.org).pdf',
#  'spam.py',
#  'spam.py.bak',
#  'SQL basic .ipynb',
#  'sql day 2 .ipynb',
#  'SQLLITE ,map ,reduce ,filter,zip.ipynb',
#  'Start Menu',
#  'swm.pem',
#  'Templates',
#  'test.log',
#  'test1.py',
#  'test2.log',
#  'test2.py',
#  'test2.py.bak',
#  'test3.log',
#  'test4',
#  'test4.log',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Untitled10.ipynb',
#  'Untitled11.ipynb',
#  'Untitled12.ipynb',
#  'Untitled13.ipynb',
#  'Untitled14.ipynb',
#  'Untitled15.ipynb',
#  'Untitled16.ipynb',
#  'Untitled17.ipynb',
#  'Untitled18.ipynb',
#  'Untitled19.ipynb',
#  'Untitled2.ipynb',
#  'Untitled20.ipynb',
#  'Untitled21.ipynb',
#  'Untitled22.ipynb',
#  'Untitled23.ipynb',
#  'Untitled24.ipynb',
#  'Untitled25.ipynb',
#  'Untitled26.ipynb',
#  'Untitled27.ipynb',
#  'Untitled28.ipynb',
#  'Untitled29.ipynb',
#  'Untitled3.ipynb',
#  'Untitled30.ipynb',
#  'Untitled31.ipynb',
#  'Untitled32.ipynb',
#  'Untitled33.ipynb',
#  'Untitled34.ipynb',
#  'Untitled35.ipynb',
#  'Untitled36.ipynb',
#  'Untitled37.ipynb',
#  'Untitled38.ipynb',
#  'Untitled39.ipynb',
#  'Untitled4.ipynb',
#  'Untitled40.ipynb',
#  'Untitled41.ipynb',
#  'Untitled42.ipynb',
#  'Untitled43.ipynb',
#  'Untitled44.ipynb',
#  'Untitled45.ipynb',
#  'Untitled5.ipynb',
#  'Untitled6.ipynb',
#  'Untitled7.ipynb',
#  'Untitled8.ipynb',
#  'Untitled9.ipynb',
#  'Videos',
#  'WLSCompanion',
#  '__pycache__']

# %%
import shutil,os
def selectiveCopy(folder,extensions,destfolder):
            folder=os.path.abspath(folder)
            destfolder=os.path.abspath(destfolder)
            for foldername, subfolders, filenames in os.walk(folder):
                for filename in filenames:
                         name, extension = os.path.splitext(filename)
                         if extension in extensions:
                                    print(" "+filename)
                                    fileAbsPath = foldername + os.path.sep + filename
                                    print('Copying', fileAbsPath, 'to', destfolder)
                                    shutil.copy(fileAbsPath, destfolder)
                                    print("done")

# %%
extensions = ['.pdf', '.py']
folder='C:\\Users\\narsi'
destfolder='D:\\location'
selectiveCopy(folder, extensions, destfolder)
# Out:
#  bumchik.py
# Copying C:\Users\narsi\bumchik.py to D:\location
# done
#  Die Design Fundamentals (J Paquin, Robert Crowley) (z-lib.org).pdf
# Copying C:\Users\narsi\Die Design Fundamentals (J Paquin, Robert Crowley) (z-lib.org).pdf to D:\location
# done
#  Fundamentals of Tool Design, 6th Edition (Evans, John W. Hill, Mark Nee etc.) (z-lib.org).pdf
# Copying C:\Users\narsi\Fundamentals of Tool Design, 6th Edition (Evans, John W. Hill, Mark Nee etc.) (z-lib.org).pdf to D:\location
# done
#  Handbook of Die Design (Ivana Suchy) (z-lib.org).pdf
# Copying C:\Users\narsi\Handbook of Die Design (Ivana Suchy) (z-lib.org).pdf to D:\location
# done
#  Jigs and Fixtures Design Manual (Prakash Joshi) (z-lib.org).pdf
# Copying C:\Users\narsi\Jigs and Fixtures Design Manual (Prakash Joshi) (z-lib.org).pdf to D:\location
# done
#  mydict.py
# Copying C:\Users\narsi\mydict.py to D:\location
# done
#  mym.py
# Copying C:\Users\narsi\mym.py to D:\location
# done
#  new1.py
# Copying C:\Users\narsi\new1.py to D:\location
# done
#  Sheet metal forming processes and die design (Boljanovic, Vukota) (z-lib.org).pdf
# Copying C:\Users\narsi\Sheet metal forming processes and die design (Boljanovic, Vukota) (z-lib.org).pdf to D:\location
# done
#  spam.py
# Copying C:\Users\narsi\spam.py to D:\location
# done
#  test1.py
# Copying C:\Users\narsi\test1.py to D:\location
# done
#  test2.py
# Copying C:\Users\narsi\test2.py to D:\location
# done
#  cwp.py
# Copying C:\Users\narsi\anaconda3\cwp.py to D:\location
# done
#  abc.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\abc.py to D:\location
# done
#  aifc.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\aifc.py to D:\location
# done
#  antigravity.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\antigravity.py to D:\location
# done
#  argparse.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\argparse.py to D:\location
# done
#  ast.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ast.py to D:\location
# done
#  asynchat.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\asynchat.py to D:\location
# done
#  asyncore.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\asyncore.py to D:\location
# done
#  base64.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\base64.py to D:\location
# done
#  bdb.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\bdb.py to D:\location
# done
#  binhex.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\binhex.py to D:\location
# done
#  bisect.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\bisect.py to D:\location
# done
#  bz2.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\bz2.py to D:\location
# done
#  calendar.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\calendar.py to D:\location
# done
#  cgi.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\cgi.py to D:\location
# done
#  cgitb.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\cgitb.py to D:\location
# done
#  chunk.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\chunk.py to D:\location
# done
#  cmd.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\cmd.py to D:\location
# done
#  code.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\code.py to D:\location
# done
#  codecs.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\codecs.py to D:\location
# done
#  codeop.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\codeop.py to D:\location
# done
#  colorsys.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\colorsys.py to D:\location
# done
#  compileall.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\compileall.py to D:\location
# done
#  configparser.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\configparser.py to D:\location
# done
#  contextlib.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\contextlib.py to D:\location
# done
#  contextvars.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\contextvars.py to D:\location
# done
#  copy.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\copy.py to D:\location
# done
#  copyreg.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\copyreg.py to D:\location
# done
#  cProfile.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\cProfile.py to D:\location
# done
#  crypt.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\crypt.py to D:\location
# done
#  csv.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\csv.py to D:\location
# done
#  dataclasses.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\dataclasses.py to D:\location
# done
#  datetime.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\datetime.py to D:\location
# done
#  decimal.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\decimal.py to D:\location
# done
#  difflib.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\difflib.py to D:\location
# done
#  dis.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\dis.py to D:\location
# done
#  doctest.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\doctest.py to D:\location
# done
#  dummy_threading.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\dummy_threading.py to D:\location
# done
#  enum.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\enum.py to D:\location
# done
#  filecmp.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\filecmp.py to D:\location
# done
#  fileinput.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\fileinput.py to D:\location
# done
#  fnmatch.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\fnmatch.py to D:\location
# done
#  formatter.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\formatter.py to D:\location
# done
#  fractions.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\fractions.py to D:\location
# done
#  ftplib.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ftplib.py to D:\location
# done
#  functools.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\functools.py to D:\location
# done
#  genericpath.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\genericpath.py to D:\location
# done
#  getopt.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\getopt.py to D:\location
# done
#  getpass.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\getpass.py to D:\location
# done
#  gettext.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\gettext.py to D:\location
# done
#  glob.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\glob.py to D:\location
# done
#  gzip.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\gzip.py to D:\location
# done
#  hashlib.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\hashlib.py to D:\location
# done
#  heapq.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\heapq.py to D:\location
# done
#  hmac.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\hmac.py to D:\location
# done
#  imaplib.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\imaplib.py to D:\location
# done
#  imghdr.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\imghdr.py to D:\location
# done
#  imp.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\imp.py to D:\location
# done
#  inspect.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\inspect.py to D:\location
# done
#  io.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\io.py to D:\location
# done
#  ipaddress.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ipaddress.py to D:\location
# done
#  keyword.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\keyword.py to D:\location
# done
#  linecache.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\linecache.py to D:\location
# done
#  locale.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\locale.py to D:\location
# done
#  lzma.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\lzma.py to D:\location
# done
#  mailbox.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\mailbox.py to D:\location
# done
#  mailcap.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\mailcap.py to D:\location
# done
#  mimetypes.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\mimetypes.py to D:\location
# done
#  modulefinder.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\modulefinder.py to D:\location
# done
#  netrc.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\netrc.py to D:\location
# done
#  nntplib.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\nntplib.py to D:\location
# done
#  ntpath.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ntpath.py to D:\location
# done
#  nturl2path.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\nturl2path.py to D:\location
# done
#  numbers.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\numbers.py to D:\location
# done
#  opcode.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\opcode.py to D:\location
# done
#  operator.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\operator.py to D:\location
# done
#  optparse.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\optparse.py to D:\location
# done
#  os.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\os.py to D:\location
# done
#  pathlib.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\pathlib.py to D:\location
# done
#  pdb.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\pdb.py to D:\location
# done
#  pickle.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\pickle.py to D:\location
# done
#  pickletools.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\pickletools.py to D:\location
# done
#  pipes.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\pipes.py to D:\location
# done
#  pkgutil.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\pkgutil.py to D:\location
# done
#  platform.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\platform.py to D:\location
# done
#  plistlib.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\plistlib.py to D:\location
# done
#  poplib.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\poplib.py to D:\location
# done
#  posixpath.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\posixpath.py to D:\location
# done
#  pprint.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\pprint.py to D:\location
# done
#  profile.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\profile.py to D:\location
# done
#  pstats.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\pstats.py to D:\location
# done
#  pty.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\pty.py to D:\location
# done
#  pyclbr.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\pyclbr.py to D:\location
# done
#  pydoc.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\pydoc.py to D:\location
# done
#  py_compile.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\py_compile.py to D:\location
# done
#  queue.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\queue.py to D:\location
# done
#  quopri.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\quopri.py to D:\location
# done
#  random.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\random.py to D:\location
# done
#  re.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\re.py to D:\location
# done
#  reprlib.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\reprlib.py to D:\location
# done
#  rlcompleter.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\rlcompleter.py to D:\location
# done
#  runpy.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\runpy.py to D:\location
# done
#  sched.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\sched.py to D:\location
# done
#  secrets.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\secrets.py to D:\location
# done
#  selectors.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\selectors.py to D:\location
# done
#  shelve.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\shelve.py to D:\location
# done
#  shlex.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\shlex.py to D:\location
# done
#  shutil.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\shutil.py to D:\location
# done
#  signal.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\signal.py to D:\location
# done
#  site.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\site.py to D:\location
# done
#  smtpd.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\smtpd.py to D:\location
# done
#  smtplib.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\smtplib.py to D:\location
# done
#  sndhdr.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\sndhdr.py to D:\location
# done
#  socket.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\socket.py to D:\location
# done
#  socketserver.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\socketserver.py to D:\location
# done
#  sre_compile.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\sre_compile.py to D:\location
# done
#  sre_constants.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\sre_constants.py to D:\location
# done
#  sre_parse.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\sre_parse.py to D:\location
# done
#  ssl.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ssl.py to D:\location
# done
#  stat.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\stat.py to D:\location
# done
#  statistics.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\statistics.py to D:\location
# done
#  string.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\string.py to D:\location
# done
#  stringprep.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\stringprep.py to D:\location
# done
#  struct.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\struct.py to D:\location
# done
#  subprocess.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\subprocess.py to D:\location
# done
#  sunau.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\sunau.py to D:\location
# done
#  symbol.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\symbol.py to D:\location
# done
#  symtable.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\symtable.py to D:\location
# done
#  sysconfig.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\sysconfig.py to D:\location
# done
#  tabnanny.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\tabnanny.py to D:\location
# done
#  tarfile.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\tarfile.py to D:\location
# done
#  telnetlib.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\telnetlib.py to D:\location
# done
#  tempfile.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\tempfile.py to D:\location
# done
#  textwrap.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\textwrap.py to D:\location
# done
#  this.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\this.py to D:\location
# done
#  threading.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\threading.py to D:\location
# done
#  timeit.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\timeit.py to D:\location
# done
#  token.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\token.py to D:\location
# done
#  tokenize.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\tokenize.py to D:\location
# done
#  trace.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\trace.py to D:\location
# done
#  traceback.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\traceback.py to D:\location
# done
#  tracemalloc.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\tracemalloc.py to D:\location
# done
#  tty.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\tty.py to D:\location
# done
#  turtle.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\turtle.py to D:\location
# done
#  types.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\types.py to D:\location
# done
#  typing.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\typing.py to D:\location
# done
#  uu.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\uu.py to D:\location
# done
#  uuid.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\uuid.py to D:\location
# done
#  warnings.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\warnings.py to D:\location
# done
#  wave.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\wave.py to D:\location
# done
#  weakref.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\weakref.py to D:\location
# done
#  webbrowser.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\webbrowser.py to D:\location
# done
#  xdrlib.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\xdrlib.py to D:\location
# done
#  zipapp.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\zipapp.py to D:\location
# done
#  zipfile.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\zipfile.py to D:\location
# done
#  zipimport.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\zipimport.py to D:\location
# done
#  _bootlocale.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\_bootlocale.py to D:\location
# done
#  _collections_abc.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\_collections_abc.py to D:\location
# done
#  _compat_pickle.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\_compat_pickle.py to D:\location
# done
#  _compression.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\_compression.py to D:\location
# done
#  _dummy_thread.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\_dummy_thread.py to D:\location
# done
#  _markupbase.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\_markupbase.py to D:\location
# done
#  _osx_support.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\_osx_support.py to D:\location
# done
#  _pydecimal.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\_pydecimal.py to D:\location
# done
#  _pyio.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\_pyio.py to D:\location
# done
#  _py_abc.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\_py_abc.py to D:\location
# done
#  _sitebuiltins.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\_sitebuiltins.py to D:\location
# done
#  _strptime.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\_strptime.py to D:\location
# done
#  _threading_local.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\_threading_local.py to D:\location
# done
#  _weakrefset.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\_weakrefset.py to D:\location
# done
#  __future__.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\__future__.py to D:\location
# done
#  __phello__.foo.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\__phello__.foo.py to D:\location
# done
#  base_events.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\asyncio\base_events.py to D:\location
# done
#  base_futures.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\asyncio\base_futures.py to D:\location
# done
#  base_subprocess.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\asyncio\base_subprocess.py to D:\location
# done
#  base_tasks.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\asyncio\base_tasks.py to D:\location
# done
#  constants.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\asyncio\constants.py to D:\location
# done
#  coroutines.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\asyncio\coroutines.py to D:\location
# done
#  events.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\asyncio\events.py to D:\location
# done
#  exceptions.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\asyncio\exceptions.py to D:\location
# done
#  format_helpers.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\asyncio\format_helpers.py to D:\location
# done
#  futures.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\asyncio\futures.py to D:\location
# done
#  locks.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\asyncio\locks.py to D:\location
# done
#  log.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\asyncio\log.py to D:\location
# done
#  proactor_events.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\asyncio\proactor_events.py to D:\location
# done
#  protocols.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\asyncio\protocols.py to D:\location
# done
#  queues.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\asyncio\queues.py to D:\location
# done
#  runners.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\asyncio\runners.py to D:\location
# done
#  selector_events.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\asyncio\selector_events.py to D:\location
# done
#  sslproto.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\asyncio\sslproto.py to D:\location
# done
#  staggered.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\asyncio\staggered.py to D:\location
# done
#  streams.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\asyncio\streams.py to D:\location
# done
#  subprocess.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\asyncio\subprocess.py to D:\location
# done
#  tasks.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\asyncio\tasks.py to D:\location
# done
#  transports.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\asyncio\transports.py to D:\location
# done
#  trsock.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\asyncio\trsock.py to D:\location
# done
#  unix_events.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\asyncio\unix_events.py to D:\location
# done
#  windows_events.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\asyncio\windows_events.py to D:\location
# done
#  windows_utils.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\asyncio\windows_utils.py to D:\location
# done
#  __init__.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\asyncio\__init__.py to D:\location
# done
#  __main__.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\asyncio\__main__.py to D:\location
# done
#  abc.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\collections\abc.py to D:\location
# done
#  __init__.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\collections\__init__.py to D:\location
# done
#  __init__.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\concurrent\__init__.py to D:\location
# done
#  process.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\concurrent\futures\process.py to D:\location
# done
#  thread.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\concurrent\futures\thread.py to D:\location
# done
#  _base.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\concurrent\futures\_base.py to D:\location
# done
#  __init__.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\concurrent\futures\__init__.py to D:\location
# done
#  util.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\util.py to D:\location
# done
#  wintypes.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\wintypes.py to D:\location
# done
#  _aix.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\_aix.py to D:\location
# done
#  _endian.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\_endian.py to D:\location
# done
#  __init__.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\__init__.py to D:\location
# done
#  dyld.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\macholib\dyld.py to D:\location
# done
#  dylib.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\macholib\dylib.py to D:\location
# done
#  framework.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\macholib\framework.py to D:\location
# done
#  __init__.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\macholib\__init__.py to D:\location
# done
#  test_anon.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\test\test_anon.py to D:\location
# done
#  test_arrays.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\test\test_arrays.py to D:\location
# done
#  test_array_in_pointer.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\test\test_array_in_pointer.py to D:\location
# done
#  test_as_parameter.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\test\test_as_parameter.py to D:\location
# done
#  test_bitfields.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\test\test_bitfields.py to D:\location
# done
#  test_buffers.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\test\test_buffers.py to D:\location
# done
#  test_bytes.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\test\test_bytes.py to D:\location
# done
#  test_byteswap.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\test\test_byteswap.py to D:\location
# done
#  test_callbacks.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\test\test_callbacks.py to D:\location
# done
#  test_cast.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\test\test_cast.py to D:\location
# done
#  test_cfuncs.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\test\test_cfuncs.py to D:\location
# done
#  test_checkretval.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\test\test_checkretval.py to D:\location
# done
#  test_delattr.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\test\test_delattr.py to D:\location
# done
#  test_errno.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\test\test_errno.py to D:\location
# done
#  test_find.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\test\test_find.py to D:\location
# done
#  test_frombuffer.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\test\test_frombuffer.py to D:\location
# done
#  test_funcptr.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\test\test_funcptr.py to D:\location
# done
#  test_functions.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\test\test_functions.py to D:\location
# done
#  test_incomplete.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\test\test_incomplete.py to D:\location
# done
#  test_init.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\test\test_init.py to D:\location
# done
#  test_internals.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\test\test_internals.py to D:\location
# done
#  test_keeprefs.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\test\test_keeprefs.py to D:\location
# done
#  test_libc.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\test\test_libc.py to D:\location
# done
#  test_loading.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\test\test_loading.py to D:\location
# done
#  test_macholib.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\test\test_macholib.py to D:\location
# done
#  test_memfunctions.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\test\test_memfunctions.py to D:\location
# done
#  test_numbers.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\test\test_numbers.py to D:\location
# done
#  test_objects.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\test\test_objects.py to D:\location
# done
#  test_parameters.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\test\test_parameters.py to D:\location
# done
#  test_pep3118.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\test\test_pep3118.py to D:\location
# done
#  test_pickling.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\test\test_pickling.py to D:\location
# done
#  test_pointers.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\test\test_pointers.py to D:\location
# done
#  test_prototypes.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\test\test_prototypes.py to D:\location
# done
#  test_python_api.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\test\test_python_api.py to D:\location
# done
#  test_random_things.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\test\test_random_things.py to D:\location
# done
#  test_refcounts.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\test\test_refcounts.py to D:\location
# done
#  test_repr.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\test\test_repr.py to D:\location
# done
#  test_returnfuncptrs.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\test\test_returnfuncptrs.py to D:\location
# done
#  test_simplesubclasses.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\test\test_simplesubclasses.py to D:\location
# done
#  test_sizes.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\test\test_sizes.py to D:\location
# done
#  test_slicing.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\test\test_slicing.py to D:\location
# done
#  test_stringptr.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\test\test_stringptr.py to D:\location
# done
#  test_strings.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\test\test_strings.py to D:\location
# done
#  test_structures.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\test\test_structures.py to D:\location
# done
#  test_struct_fields.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\test\test_struct_fields.py to D:\location
# done
#  test_unaligned_structures.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\test\test_unaligned_structures.py to D:\location
# done
#  test_unicode.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\test\test_unicode.py to D:\location
# done
#  test_values.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\test\test_values.py to D:\location
# done
#  test_varsize_struct.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\test\test_varsize_struct.py to D:\location
# done
#  test_win32.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\test\test_win32.py to D:\location
# done
#  test_wintypes.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\test\test_wintypes.py to D:\location
# done
#  __init__.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\test\__init__.py to D:\location
# done
#  __main__.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\ctypes\test\__main__.py to D:\location
# done
#  ascii.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\curses\ascii.py to D:\location
# done
#  has_key.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\curses\has_key.py to D:\location
# done
#  panel.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\curses\panel.py to D:\location
# done
#  textpad.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\curses\textpad.py to D:\location
# done
#  __init__.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\curses\__init__.py to D:\location
# done
#  dumb.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\dbm\dumb.py to D:\location
# done
#  gnu.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\dbm\gnu.py to D:\location
# done
#  ndbm.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\dbm\ndbm.py to D:\location
# done
#  __init__.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\dbm\__init__.py to D:\location
# done
#  archive_util.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\archive_util.py to D:\location
# done
#  bcppcompiler.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\bcppcompiler.py to D:\location
# done
#  ccompiler.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\ccompiler.py to D:\location
# done
#  cmd.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\cmd.py to D:\location
# done
#  config.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\config.py to D:\location
# done
#  core.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\core.py to D:\location
# done
#  cygwinccompiler.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\cygwinccompiler.py to D:\location
# done
#  debug.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\debug.py to D:\location
# done
#  dep_util.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\dep_util.py to D:\location
# done
#  dir_util.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\dir_util.py to D:\location
# done
#  dist.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\dist.py to D:\location
# done
#  errors.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\errors.py to D:\location
# done
#  extension.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\extension.py to D:\location
# done
#  fancy_getopt.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\fancy_getopt.py to D:\location
# done
#  filelist.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\filelist.py to D:\location
# done
#  file_util.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\file_util.py to D:\location
# done
#  log.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\log.py to D:\location
# done
#  msvc9compiler.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\msvc9compiler.py to D:\location
# done
#  msvccompiler.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\msvccompiler.py to D:\location
# done
#  spawn.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\spawn.py to D:\location
# done
#  sysconfig.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\sysconfig.py to D:\location
# done
#  text_file.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\text_file.py to D:\location
# done
#  unixccompiler.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\unixccompiler.py to D:\location
# done
#  util.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\util.py to D:\location
# done
#  version.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\version.py to D:\location
# done
#  versionpredicate.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\versionpredicate.py to D:\location
# done
#  _msvccompiler.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\_msvccompiler.py to D:\location
# done
#  __init__.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\__init__.py to D:\location
# done
#  bdist.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\command\bdist.py to D:\location
# done
#  bdist_dumb.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\command\bdist_dumb.py to D:\location
# done
#  bdist_msi.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\command\bdist_msi.py to D:\location
# done
#  bdist_rpm.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\command\bdist_rpm.py to D:\location
# done
#  bdist_wininst.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\command\bdist_wininst.py to D:\location
# done
#  build.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\command\build.py to D:\location
# done
#  build_clib.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\command\build_clib.py to D:\location
# done
#  build_ext.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\command\build_ext.py to D:\location
# done
#  build_py.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\command\build_py.py to D:\location
# done
#  build_scripts.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\command\build_scripts.py to D:\location
# done
#  check.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\command\check.py to D:\location
# done
#  clean.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\command\clean.py to D:\location
# done
#  config.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\command\config.py to D:\location
# done
#  install.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\command\install.py to D:\location
# done
#  install_data.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\command\install_data.py to D:\location
# done
#  install_egg_info.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\command\install_egg_info.py to D:\location
# done
#  install_headers.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\command\install_headers.py to D:\location
# done
#  install_lib.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\command\install_lib.py to D:\location
# done
#  install_scripts.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\command\install_scripts.py to D:\location
# done
#  register.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\command\register.py to D:\location
# done
#  sdist.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\command\sdist.py to D:\location
# done
#  upload.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\command\upload.py to D:\location
# done
#  __init__.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\command\__init__.py to D:\location
# done
#  support.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\tests\support.py to D:\location
# done
#  test_archive_util.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\tests\test_archive_util.py to D:\location
# done
#  test_bdist.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\tests\test_bdist.py to D:\location
# done
#  test_bdist_dumb.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\tests\test_bdist_dumb.py to D:\location
# done
#  test_bdist_msi.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\tests\test_bdist_msi.py to D:\location
# done
#  test_bdist_rpm.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\tests\test_bdist_rpm.py to D:\location
# done
#  test_bdist_wininst.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\tests\test_bdist_wininst.py to D:\location
# done
#  test_build.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\tests\test_build.py to D:\location
# done
#  test_build_clib.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\tests\test_build_clib.py to D:\location
# done
#  test_build_ext.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\tests\test_build_ext.py to D:\location
# done
#  test_build_py.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\tests\test_build_py.py to D:\location
# done
#  test_build_scripts.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\tests\test_build_scripts.py to D:\location
# done
#  test_check.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\tests\test_check.py to D:\location
# done
#  test_clean.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\tests\test_clean.py to D:\location
# done
#  test_cmd.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\tests\test_cmd.py to D:\location
# done
#  test_config.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\tests\test_config.py to D:\location
# done
#  test_config_cmd.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\tests\test_config_cmd.py to D:\location
# done
#  test_core.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\tests\test_core.py to D:\location
# done
#  test_cygwinccompiler.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\tests\test_cygwinccompiler.py to D:\location
# done
#  test_dep_util.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\tests\test_dep_util.py to D:\location
# done
#  test_dir_util.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\tests\test_dir_util.py to D:\location
# done
#  test_dist.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\tests\test_dist.py to D:\location
# done
#  test_extension.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\tests\test_extension.py to D:\location
# done
#  test_filelist.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\tests\test_filelist.py to D:\location
# done
#  test_file_util.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\tests\test_file_util.py to D:\location
# done
#  test_install.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\tests\test_install.py to D:\location
# done
#  test_install_data.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\tests\test_install_data.py to D:\location
# done
#  test_install_headers.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\tests\test_install_headers.py to D:\location
# done
#  test_install_lib.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\tests\test_install_lib.py to D:\location
# done
#  test_install_scripts.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\tests\test_install_scripts.py to D:\location
# done
#  test_log.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\tests\test_log.py to D:\location
# done
#  test_msvc9compiler.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\tests\test_msvc9compiler.py to D:\location
# done
#  test_msvccompiler.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\tests\test_msvccompiler.py to D:\location
# done
#  test_register.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\tests\test_register.py to D:\location
# done
#  test_sdist.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\tests\test_sdist.py to D:\location
# done
#  test_spawn.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\tests\test_spawn.py to D:\location
# done
#  test_sysconfig.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\tests\test_sysconfig.py to D:\location
# done
#  test_text_file.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\tests\test_text_file.py to D:\location
# done
#  test_unixccompiler.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\tests\test_unixccompiler.py to D:\location
# done
#  test_upload.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\tests\test_upload.py to D:\location
# done
#  test_util.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\tests\test_util.py to D:\location
# done
#  test_version.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\tests\test_version.py to D:\location
# done
#  test_versionpredicate.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\tests\test_versionpredicate.py to D:\location
# done
#  __init__.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\distutils\tests\__init__.py to D:\location
# done
#  base64mime.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\email\base64mime.py to D:\location
# done
#  charset.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\email\charset.py to D:\location
# done
#  contentmanager.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\email\contentmanager.py to D:\location
# done
#  encoders.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\email\encoders.py to D:\location
# done
#  errors.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\email\errors.py to D:\location
# done
#  feedparser.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\email\feedparser.py to D:\location
# done
#  generator.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\email\generator.py to D:\location
# done
#  header.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\email\header.py to D:\location
# done
#  headerregistry.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\email\headerregistry.py to D:\location
# done
#  iterators.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\email\iterators.py to D:\location
# done
#  message.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\email\message.py to D:\location
# done
#  parser.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\email\parser.py to D:\location
# done
#  policy.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\email\policy.py to D:\location
# done
#  quoprimime.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\email\quoprimime.py to D:\location
# done
#  utils.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\email\utils.py to D:\location
# done
#  _encoded_words.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\email\_encoded_words.py to D:\location
# done
#  _header_value_parser.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\email\_header_value_parser.py to D:\location
# done
#  _parseaddr.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\email\_parseaddr.py to D:\location
# done
#  _policybase.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\email\_policybase.py to D:\location
# done
#  __init__.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\email\__init__.py to D:\location
# done
#  application.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\email\mime\application.py to D:\location
# done
#  audio.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\email\mime\audio.py to D:\location
# done
#  base.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\email\mime\base.py to D:\location
# done
#  image.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\email\mime\image.py to D:\location
# done
#  message.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\email\mime\message.py to D:\location
# done
#  multipart.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\email\mime\multipart.py to D:\location
# done
#  nonmultipart.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\email\mime\nonmultipart.py to D:\location
# done
#  text.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\email\mime\text.py to D:\location
# done
#  __init__.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\email\mime\__init__.py to D:\location
# done
#  aliases.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\encodings\aliases.py to D:\location
# done
#  ascii.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\encodings\ascii.py to D:\location
# done
#  base64_codec.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\encodings\base64_codec.py to D:\location
# done
#  big5.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\encodings\big5.py to D:\location
# done
#  big5hkscs.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\encodings\big5hkscs.py to D:\location
# done
#  bz2_codec.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\encodings\bz2_codec.py to D:\location
# done
#  charmap.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\encodings\charmap.py to D:\location
# done
#  cp037.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\encodings\cp037.py to D:\location
# done
#  cp1006.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\encodings\cp1006.py to D:\location
# done
#  cp1026.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\encodings\cp1026.py to D:\location
# done
#  cp1125.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\encodings\cp1125.py to D:\location
# done
#  cp1140.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\encodings\cp1140.py to D:\location
# done
#  cp1250.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\encodings\cp1250.py to D:\location
# done
#  cp1251.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\encodings\cp1251.py to D:\location
# done
#  cp1252.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\encodings\cp1252.py to D:\location
# done
#  cp1253.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\encodings\cp1253.py to D:\location
# done
#  cp1254.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\encodings\cp1254.py to D:\location
# done
#  cp1255.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\encodings\cp1255.py to D:\location
# done
#  cp1256.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\encodings\cp1256.py to D:\location
# done
#  cp1257.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\encodings\cp1257.py to D:\location
# done
#  cp1258.py
# Copying C:\Users\narsi\anaconda3\envs\ImageScrapper\Lib\encodings\cp1258.py to D:\location
# done
#  cp273.py
# ...
# done
#  __init__.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Lib\unittest\test\testmock\__init__.py to D:\location
# done
#  __main__.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Lib\unittest\test\testmock\__main__.py to D:\location
# done
#  error.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Lib\urllib\error.py to D:\location
# done
#  parse.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Lib\urllib\parse.py to D:\location
# done
#  request.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Lib\urllib\request.py to D:\location
# done
#  response.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Lib\urllib\response.py to D:\location
# done
#  robotparser.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Lib\urllib\robotparser.py to D:\location
# done
#  __init__.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Lib\urllib\__init__.py to D:\location
# done
#  __init__.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Lib\venv\__init__.py to D:\location
# done
#  __main__.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Lib\venv\__main__.py to D:\location
# done
#  handlers.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Lib\wsgiref\handlers.py to D:\location
# done
#  headers.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Lib\wsgiref\headers.py to D:\location
# done
#  simple_server.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Lib\wsgiref\simple_server.py to D:\location
# done
#  util.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Lib\wsgiref\util.py to D:\location
# done
#  validate.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Lib\wsgiref\validate.py to D:\location
# done
#  __init__.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Lib\wsgiref\__init__.py to D:\location
# done
#  __init__.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Lib\xml\__init__.py to D:\location
# done
#  domreg.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Lib\xml\dom\domreg.py to D:\location
# done
#  expatbuilder.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Lib\xml\dom\expatbuilder.py to D:\location
# done
#  minicompat.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Lib\xml\dom\minicompat.py to D:\location
# done
#  minidom.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Lib\xml\dom\minidom.py to D:\location
# done
#  NodeFilter.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Lib\xml\dom\NodeFilter.py to D:\location
# done
#  pulldom.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Lib\xml\dom\pulldom.py to D:\location
# done
#  xmlbuilder.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Lib\xml\dom\xmlbuilder.py to D:\location
# done
#  __init__.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Lib\xml\dom\__init__.py to D:\location
# done
#  cElementTree.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Lib\xml\etree\cElementTree.py to D:\location
# done
#  ElementInclude.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Lib\xml\etree\ElementInclude.py to D:\location
# done
#  ElementPath.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Lib\xml\etree\ElementPath.py to D:\location
# done
#  ElementTree.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Lib\xml\etree\ElementTree.py to D:\location
# done
#  __init__.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Lib\xml\etree\__init__.py to D:\location
# done
#  expat.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Lib\xml\parsers\expat.py to D:\location
# done
#  __init__.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Lib\xml\parsers\__init__.py to D:\location
# done
#  expatreader.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Lib\xml\sax\expatreader.py to D:\location
# done
#  handler.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Lib\xml\sax\handler.py to D:\location
# done
#  saxutils.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Lib\xml\sax\saxutils.py to D:\location
# done
#  xmlreader.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Lib\xml\sax\xmlreader.py to D:\location
# done
#  _exceptions.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Lib\xml\sax\_exceptions.py to D:\location
# done
#  __init__.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Lib\xml\sax\__init__.py to D:\location
# done
#  client.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Lib\xmlrpc\client.py to D:\location
# done
#  server.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Lib\xmlrpc\server.py to D:\location
# done
#  __init__.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Lib\xmlrpc\__init__.py to D:\location
# done
#  _common.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Lib\zoneinfo\_common.py to D:\location
# done
#  _tzpath.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Lib\zoneinfo\_tzpath.py to D:\location
# done
#  _zoneinfo.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Lib\zoneinfo\_zoneinfo.py to D:\location
# done
#  __init__.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Lib\zoneinfo\__init__.py to D:\location
# done
#  2to3-script.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Scripts\2to3-script.py to D:\location
# done
#  idle-script.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Scripts\idle-script.py to D:\location
# done
#  pip-script.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Scripts\pip-script.py to D:\location
# done
#  pip3-script.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Scripts\pip3-script.py to D:\location
# done
#  pydoc-script.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Scripts\pydoc-script.py to D:\location
# done
#  wheel-script.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Scripts\wheel-script.py to D:\location
# done
#  beer.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\demo\beer.py to D:\location
# done
#  eiffel.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\demo\eiffel.py to D:\location
# done
#  hanoi.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\demo\hanoi.py to D:\location
# done
#  life.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\demo\life.py to D:\location
# done
#  markov.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\demo\markov.py to D:\location
# done
#  mcast.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\demo\mcast.py to D:\location
# done
#  queens.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\demo\queens.py to D:\location
# done
#  redemo.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\demo\redemo.py to D:\location
# done
#  rpython.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\demo\rpython.py to D:\location
# done
#  rpythond.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\demo\rpythond.py to D:\location
# done
#  sortvisu.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\demo\sortvisu.py to D:\location
# done
#  spreadsheet.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\demo\spreadsheet.py to D:\location
# done
#  vector.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\demo\vector.py to D:\location
# done
#  makelocalealias.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\i18n\makelocalealias.py to D:\location
# done
#  msgfmt.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\i18n\msgfmt.py to D:\location
# done
#  pygettext.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\i18n\pygettext.py to D:\location
# done
#  ChipViewer.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\pynche\ChipViewer.py to D:\location
# done
#  ColorDB.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\pynche\ColorDB.py to D:\location
# done
#  DetailsViewer.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\pynche\DetailsViewer.py to D:\location
# done
#  ListViewer.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\pynche\ListViewer.py to D:\location
# done
#  Main.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\pynche\Main.py to D:\location
# done
#  pyColorChooser.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\pynche\pyColorChooser.py to D:\location
# done
#  PyncheWidget.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\pynche\PyncheWidget.py to D:\location
# done
#  StripViewer.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\pynche\StripViewer.py to D:\location
# done
#  Switchboard.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\pynche\Switchboard.py to D:\location
# done
#  TextViewer.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\pynche\TextViewer.py to D:\location
# done
#  TypeinViewer.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\pynche\TypeinViewer.py to D:\location
# done
#  __init__.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\pynche\__init__.py to D:\location
# done
#  2to3.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\scripts\2to3.py to D:\location
# done
#  abitype.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\scripts\abitype.py to D:\location
# done
#  analyze_dxp.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\scripts\analyze_dxp.py to D:\location
# done
#  byext.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\scripts\byext.py to D:\location
# done
#  byteyears.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\scripts\byteyears.py to D:\location
# done
#  checkpip.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\scripts\checkpip.py to D:\location
# done
#  cleanfuture.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\scripts\cleanfuture.py to D:\location
# done
#  combinerefs.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\scripts\combinerefs.py to D:\location
# done
#  copytime.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\scripts\copytime.py to D:\location
# done
#  crlf.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\scripts\crlf.py to D:\location
# done
#  db2pickle.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\scripts\db2pickle.py to D:\location
# done
#  diff.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\scripts\diff.py to D:\location
# done
#  dutree.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\scripts\dutree.py to D:\location
# done
#  eptags.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\scripts\eptags.py to D:\location
# done
#  find-uname.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\scripts\find-uname.py to D:\location
# done
#  finddiv.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\scripts\finddiv.py to D:\location
# done
#  findlinksto.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\scripts\findlinksto.py to D:\location
# done
#  findnocoding.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\scripts\findnocoding.py to D:\location
# done
#  find_recursionlimit.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\scripts\find_recursionlimit.py to D:\location
# done
#  fixcid.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\scripts\fixcid.py to D:\location
# done
#  fixdiv.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\scripts\fixdiv.py to D:\location
# done
#  fixheader.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\scripts\fixheader.py to D:\location
# done
#  fixnotice.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\scripts\fixnotice.py to D:\location
# done
#  fixps.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\scripts\fixps.py to D:\location
# done
#  generate_opcode_h.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\scripts\generate_opcode_h.py to D:\location
# done
#  generate_stdlib_module_names.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\scripts\generate_stdlib_module_names.py to D:\location
# done
#  generate_token.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\scripts\generate_token.py to D:\location
# done
#  get-remote-certificate.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\scripts\get-remote-certificate.py to D:\location
# done
#  google.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\scripts\google.py to D:\location
# done
#  gprof2html.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\scripts\gprof2html.py to D:\location
# done
#  highlight.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\scripts\highlight.py to D:\location
# done
#  ifdef.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\scripts\ifdef.py to D:\location
# done
#  import_diagnostics.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\scripts\import_diagnostics.py to D:\location
# done
#  lfcr.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\scripts\lfcr.py to D:\location
# done
#  linktree.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\scripts\linktree.py to D:\location
# done
#  lll.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\scripts\lll.py to D:\location
# done
#  mailerdaemon.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\scripts\mailerdaemon.py to D:\location
# done
#  make_ctype.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\scripts\make_ctype.py to D:\location
# done
#  md5sum.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\scripts\md5sum.py to D:\location
# done
#  mkreal.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\scripts\mkreal.py to D:\location
# done
#  ndiff.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\scripts\ndiff.py to D:\location
# done
#  nm2def.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\scripts\nm2def.py to D:\location
# done
#  objgraph.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\scripts\objgraph.py to D:\location
# done
#  parseentities.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\scripts\parseentities.py to D:\location
# done
#  parse_html5_entities.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\scripts\parse_html5_entities.py to D:\location
# done
#  patchcheck.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\scripts\patchcheck.py to D:\location
# done
#  pathfix.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\scripts\pathfix.py to D:\location
# done
#  pdeps.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\scripts\pdeps.py to D:\location
# done
#  pep384_macrocheck.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\scripts\pep384_macrocheck.py to D:\location
# done
#  pickle2db.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\scripts\pickle2db.py to D:\location
# done
#  pindent.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\scripts\pindent.py to D:\location
# done
#  ptags.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\scripts\ptags.py to D:\location
# done
#  pydoc3.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\scripts\pydoc3.py to D:\location
# done
#  pysource.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\scripts\pysource.py to D:\location
# done
#  reindent-rst.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\scripts\reindent-rst.py to D:\location
# done
#  reindent.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\scripts\reindent.py to D:\location
# done
#  rgrep.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\scripts\rgrep.py to D:\location
# done
#  run_tests.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\scripts\run_tests.py to D:\location
# done
#  serve.py
# Copying C:\Users\narsi\anaconda3\envs\Music\Tools\scripts\serve.py to D:\location
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-95f02b4e5200> in <module>
#       2 folder='C:\\Users\\narsi'
#       3 destfolder='D:\\location'
# ----> 4 selectiveCopy(folder, extensions, destfolder)
#
# <ipython-input-7-1c700514fcf0> in selectiveCopy(folder, extensions, destfolder)
#      10                                     fileAbsPath = foldername + os.path.sep + filename
#      11                                     print('Copying', fileAbsPath, 'to', destfolder)
# ---> 12                                     shutil.copy(fileAbsPath, destfolder)
#      13                                     print("done")
#      14
#
# ~\anaconda3\lib\shutil.py in copy(src, dst, follow_symlinks)
#     416     if os.path.isdir(dst):
#     417         dst = os.path.join(dst, os.path.basename(src))
# --> 418     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     419     copymode(src, dst, follow_symlinks=follow_symlinks)
#     420     return dst
#
# ~\anaconda3\lib\shutil.py in copyfile(src, dst, follow_symlinks)
#     280             # https://github.com/python/cpython/pull/7160#discussion_r195405230
#     281             elif _WINDOWS and file_size > 0:
# --> 282                 _copyfileobj_readinto(fsrc, fdst, min(file_size, COPY_BUFSIZE))
#     283                 return dst
#     284
#
# ~\anaconda3\lib\shutil.py in _copyfileobj_readinto(fsrc, fdst, length)
#     186     with memoryview(bytearray(length)) as mv:
#     187         while True:
# --> 188             n = fsrc_readinto(mv)
#     189             if not n:
#     190                 break
#
# KeyboardInterrupt:

# %%
for foldername, subfolders, filenames in os.walk(folder):
		for filename in filenames:
			name, extension = os.path.splitext(filename)
			if extension in extensions:
				
				print('Coping', fileAbsPath, 'to', destFolder)
				shutil.copy(fileAbsPath, destFolder)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-a114e3b2c4d2> in <module>
# ----> 1 for foldername, subfolders, filenames in os.walk(folder):
#       2                 for filename in filenames:
#       3                         name, extension = os.path.splitext(filename)
#       4                         if extension in extensions:
#       5
#
# NameError: name 'folder' is not defined
